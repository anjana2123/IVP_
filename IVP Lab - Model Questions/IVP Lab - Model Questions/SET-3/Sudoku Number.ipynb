# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("C:/Users/anjan/SNU/6th Sem/IVP/IVP Lab - Model Questions/IVP Lab - Model Questions/SET-3/image1004.jpg")

# %%
plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.show()

# %%
image = image[250:1120,40:900]
plt.imshow(image)
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(8, 6))
plt.imshow(gray, cmap='gray')
plt.title('Grayscale Image')
plt.show()

# %%
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# %%
plt.figure(figsize=(8, 6))
plt.imshow(blurred, cmap='gray')
plt.show()

# %%
edges = cv2.Canny(blurred, 50, 100)

plt.figure(figsize=(8, 6))
plt.imshow(edges, cmap='gray')
plt.title('Edges')
plt.show()

# %%
#import easyocr
# !pip install easyocr
# Out:
# ...
#   Using cached easyocr-1.7.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached easyocr-1.7.1-py3-none-any.whl (2.9 MB)
# Using cached opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl (38.5 MB)
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\anjan\\anaconda3\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(blurred)

for detection in result:
    box = detection[0]
    text = detection[1]
    x1, y1 = box[0][0], box[0][1]
    x2, y2 = box[2][0], box[2][1]
    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 0, 255), 2)
    cv2.putText(image, text, (x1, y1), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Image with Highlighted Numbers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 reader = easyocr.Reader(['en'])
#       2 result = reader.readtext(blurred)
#       4 for detection in result:
#
# NameError: name 'easyocr' is not defined

# %%
# Out:
# ...
#   Using cached easyocr-1.7.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached easyocr-1.7.1-py3-none-any.whl (2.9 MB)
# Using cached opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl (38.5 MB)
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\anjan\\anaconda3\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.
